# %%
from dart.src.preprocessing import prefetch_batches

# %%
path_to_read = ""
dataset = prefetch_batches(source=path_to_read)

for element in dataset:
      print(element)

# %%
# # Prepare the final data loader
# import tensorflow as tf
# AUTO = tf.data.experimental.AUTOTUNE

# # Zipping 
# trainloaders_zipped = tf.data.Dataset.zip(dataset)

# # Final trainloader
# trainloaders_zipped = (
#     trainloaders_zipped
#     .batch(32)
#     .prefetch(AUTO)
# )
